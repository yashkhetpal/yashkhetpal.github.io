# %% [markdown]
# <a href="https://colab.research.google.com/github/yashkhetpal/yashkhetpal.github.io/blob/main/Untitled0_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
df = pd.read_csv('fifa_world_cup_2026_matches.csv')
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Match_ID    104 non-null    int64
#  1   Date        104 non-null    object
#  2   Stage       104 non-null    object
#  3   Home_Team   104 non-null    object
#  4   Away_Team   104 non-null    object
#  5   Home_Goals  104 non-null    int64
#  6   Away_Goals  104 non-null    int64
#  7   Extra_Time  104 non-null    bool
#  8   Penalties   104 non-null    bool
#  9   Venue       104 non-null    object
#  10  City        104 non-null    object
#  11  Attendance  104 non-null    int64
#  12  Referee     104 non-null    object
# dtypes: bool(2), int64(4), object(7)
# memory usage: 9.3+ KB
#          Match_ID  Home_Goals  Away_Goals    Attendance
# count  104.000000  104.000000  104.000000    104.000000
# mean    52.500000    1.307692    1.182692  65318.798077
# ...
